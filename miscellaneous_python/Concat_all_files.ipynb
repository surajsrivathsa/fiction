# %%
import pandas as pd
import glob

# %%
path = r'/Users/surajshashidhar/git/fiction' # use your path
all_files = glob.glob(path + "/Features_Extracted_English_b*.csv")

print(all_files)

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

li
# Out:
# ['/Users/surajshashidhar/git/fiction/Features_Extracted_English_b9.csv', '/Users/surajshashidhar/git/fiction/Features_Extracted_English_b8.csv', '/Users/surajshashidhar/git/fiction/Features_Extracted_English_b10.csv', '/Users/surajshashidhar/git/fiction/Features_Extracted_English_b6.csv', '/Users/surajshashidhar/git/fiction/Features_Extracted_English_b7.csv', '/Users/surajshashidhar/git/fiction/Features_Extracted_English_b5.csv', '/Users/surajshashidhar/git/fiction/Features_Extracted_English_b4.csv', '/Users/surajshashidhar/git/fiction/Features_Extracted_English_b1.csv', '/Users/surajshashidhar/git/fiction/Features_Extracted_English_b3.csv', '/Users/surajshashidhar/git/fiction/Features_Extracted_English_b2.csv']
# [     bookId-chunkNo      F0      F1      F2      F3      F4      F5      F6  \
#  0         pg10556-1  0.0150  0.4335  0.0867  0.0635  0.0230  0.0313  0.0298
#  1         pg10556-2  0.0147  0.4362  0.0384  0.0531  0.0198  0.0293  0.0299
# ...

# %%
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.head(10)
# Out:
#   bookId-chunkNo      F0      F1      F2      F3      F4      F5      F6  \
# 0      pg10556-1  0.0150  0.4335  0.0867  0.0635  0.0230  0.0313  0.0298
# 1      pg10556-2  0.0147  0.4362  0.0384  0.0531  0.0198  0.0293  0.0299
# 2      pg10556-3  0.0169  0.4527  0.1289  0.0553  0.0176  0.0301  0.0318
# 3      pg10556-4  0.0172  0.3418  0.1656  0.0532  0.0217  0.0302  0.0294
# 4      pg10556-5  0.0140  0.4043  0.1835  0.0543  0.0209  0.0271  0.0327
# 5      pg10556-6  0.0142  0.3990  0.0640  0.0593  0.0219  0.0313  0.0337
# 6      pg10556-7  0.0174  0.5169  0.0904  0.0482  0.0226  0.0319  0.0296
# 7      pg10556-8  0.0175  0.3950  0.2123  0.0486  0.0199  0.0347  0.0326
# 8        pg108-1  0.0112  0.2327  0.0109  0.0811  0.0285  0.0298  0.0331
# 9        pg108-1  0.0112  0.2327  0.0109  0.0811  0.0285  0.0298  0.0331
#
#        F7      F8  ...     F15     F16     F17     F18     F19     F20  \
# 0  0.0723  0.0326  ...  0.0106  0.3182  0.3182  0.3636  0.5817  0.0620
# ...

# %%
frame.describe()
# Out:
#                  F0            F1            F2            F3            F4  \
# count  14307.000000  14307.000000  14307.000000  14307.000000  14307.000000
# mean       0.018363      0.261558      0.146241      0.076435      0.024908
# std        0.007779      0.114493      0.101411      0.017764      0.005667
# min        0.000300      0.002500      0.000000      0.000900      0.004600
# 25%        0.013100      0.180700      0.065150      0.065500      0.021200
# 50%        0.017700      0.247700      0.131000      0.077100      0.024800
# 75%        0.023000      0.326600      0.212000      0.088300      0.028500
# max        0.130800      0.796700      0.634400      0.137600      0.055300
#
#                  F5            F6            F7            F8            F9  \
# count  14307.000000  14307.000000  14307.000000  14307.000000  14307.000000
# mean       0.025574      0.034588      0.063672      0.040464      0.001184
# ...

# %%
frame.to_csv("/Users/surajshashidhar/git/fiction/Features_extracted_english_with_features2_3.csv", index = False)
